# %% [markdown]
# # Check GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Dec 12 18:58:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Run this command once and restart the runtime

# %%
# !pip install av
# Out:
# Collecting av
#   Downloading https://files.pythonhosted.org/packages/9e/62/9a992be76f8e13ce0e3a24a838191b546805545116f9fc869bd11bd21b5f/av-8.0.2-cp36-cp36m-manylinux2010_x86_64.whl (36.9MB)
#      |████████████████████████████████| 36.9MB 144kB/s
# Installing collected packages: av
# Successfully installed av-8.0.2

# %% [markdown]
# # HMDB51 + Dataloader

# %%
import glob
import os

from torchvision.datasets.utils import list_dir
from torchvision.datasets.folder import make_dataset
from torchvision.datasets.video_utils import VideoClips
from torchvision.datasets.vision import VisionDataset

class HMDB51(VisionDataset):
    """
    Internally, it uses a VideoClips object to handle clip creation.
    Args:
        root (string): Root directory of the HMDB51 Dataset.
        frames_per_clip (int): Number of frames in a clip.
        step_between_clips (int): Number of frames between each clip.
        train (bool, optional): If ``True``, creates a dataset from the train split,
            otherwise from the ``test`` split.
        transform (callable, optional): A function/transform that takes in a TxHxWxC video
            and returns a transformed version.
    Returns:
        video (Tensor[T, H, W, C]): the `T` video frames
        audio(Tensor[K, L]): the audio frames, where `K` is the number of channels
            and `L` is the number of points
        label (int): class of the video clip
    """
    def __init__(self, root=""):
        super(HMDB51, self).__init__(root)

    def init_data(self, root, frames_per_clip, step_between_clips=1,
                 frame_rate=None, train=True, transform=None,
                 _precomputed_metadata=None, num_workers=1, _video_width=0,
                 _video_height=0, _video_min_dimension=0, _audio_samples=0):
        super(HMDB51, self).__init__(root)
        extensions = ('avi',)
        if train:
            root = root + "/train"
        else:
            root = root + "/test"
        classes = sorted(list_dir(root))
        class_to_idx = {class_: i for (i, class_) in enumerate(classes)}
        print(class_to_idx)
        self.samples = []
        for target_class in sorted(class_to_idx.keys()):
            class_index = class_to_idx[target_class]
            target_dir = os.path.join(root, target_class)
            for root_curr, _, fnames in sorted(os.walk(target_dir, followlinks=True)):
                for fname in sorted(fnames):
                    path = os.path.join(root_curr, fname)
                    if os.path.isfile(path):
                        item = path, class_index
                        self.samples.append(item)

        video_paths = [path for (path, _) in self.samples]
        video_clips = VideoClips(
            video_paths,
            frames_per_clip,
            step_between_clips,
            frame_rate,
            _precomputed_metadata,
            num_workers=num_workers,
            _video_width=_video_width,
            _video_height=_video_height,
            _video_min_dimension=_video_min_dimension,
            _audio_samples=_audio_samples,
        )
        self.train = train
        self.classes = classes
        self.video_clips_metadata = video_clips.metadata
        self.indices = self.get_indices(video_paths)
        self.video_clips = video_clips.subset(self.indices)
        self.transform = transform

    @property
    def metadata(self):
        return self.video_clips_metadata

    def get_indices(self, video_list):
        indices = []
        for video_index, video_path in enumerate(video_list):
            indices.append(video_index)
        return indices

    def __len__(self):
        return self.video_clips.num_clips()

    def __getitem__(self, idx):
        video, _, _, video_idx = self.video_clips.get_clip(idx)
        sample_index = self.indices[video_idx]
        _, class_index = self.samples[sample_index]

        if self.transform is not None:
            video = video.permute(0, 3, 1, 2)
            video = self.transform(video)
            video = video.permute(0, 2, 3, 1)

        return video, class_index, sample_index

    def state_dict(self):
        state = {"video_clips": self.video_clips,
                 "indices": self.indices,
                 "samples": self.samples,
                 "transform": self.transform,
                 "metadata": self.video_clips_metadata}

        return state

    def load_state_dict(self, state):
        self.video_clips = state["video_clips"]
        self.indices = state["indices"]
        self.samples = state["samples"]
        self.transform = state["transform"]
        self.video_clips_metadata = state["metadata"]

import torch
from torch.utils.data import DataLoader

class BuildDataLoader(torch.utils.data.DataLoader):
    def __init__(self, dataset, batch_size, shuffle, num_workers):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.num_workers = num_workers
        self.w_frame = 224
        self.h_frame = 224

    # output:
    #  dict{images: (bz, 3, 800, 1088)
    #       labels: list:len(bz)
    #       masks: list:len(bz){(n_obj, 800,1088)}
    #       bbox: list:len(bz){(n_obj, 4)}
    #       index: list:len(bz)
    def collect_fn(self, batch):
        video_list = []
        label_list = []
        index_list = []

        for video, cl_index, s_index in batch:
            video_list.append(video)
            label_list.append(cl_index)
            index_list.append(s_index)

        data = {"videos": torch.stack(video_list),
                "labels": label_list,
                "indexes": index_list
                }

        return data

    def loader(self):
        return DataLoader(self.dataset,
                          batch_size=self.batch_size,
                          shuffle=self.shuffle,
                          num_workers=self.num_workers,
                          collate_fn=self.collect_fn)

# %% [markdown]
# # Optical Flow (Not currently in use)

# %%
import cv2 as cv
import numpy as np

def getOpticalFlow(videos):
    bz = videos.size(0)

    flow_list_batch = []

    for b in range(bz):
        images = videos[b]

        w = images[0].size(0)
        h = images[0].size(1)
        num_frames = images.size(0)

        prev = cv.cvtColor(images[0].numpy(), cv.COLOR_BGR2GRAY)
        flow_list = []

        # Calculate flows
        for i in range(1, num_frames):
            next = cv.cvtColor(images[i].numpy(), cv.COLOR_BGR2GRAY)
            flow_list.append(cv.calcOpticalFlowFarneback(prev, next, None, 0.5, 3, 15, 3, 5, 1.2, 0))
            prev = next.copy()

        # Perform mean flow subtraction between subsequent frames
        for i in range(len(flow_list)):
            curr_flow = flow_list[i]
            mean = np.mean(curr_flow, axis=2)
            flow_list[i][:,:,0] -= mean
            flow_list[i][:,:,1] -= mean

        # Visualize flows
        for flow in flow_list:
            hsv = np.zeros_like(images[0])
            hsv[..., 1] = 255

            mag, ang = cv.cartToPolar(flow[..., 0], flow[..., 1])
            hsv[..., 0] = ang * 180 / np.pi / 2
            hsv[..., 2] = cv.normalize(mag, None, 0, 255, cv.NORM_MINMAX)
            bgr = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
            #cv.imshow("Flow", bgr)
            #cv.waitKey(0)

        flow_list_batch.append(np.stack(flow_list, axis=-1).reshape(w, h, 2 * (num_frames - 1)))

    flows = np.stack(flow_list_batch, axis=0)
    return torch.Tensor(flows)

# %% [markdown]
# # Video Frame Stacking

# %%
from google.colab.patches import cv2_imshow

def getSG3I(videos):
    bz = videos.size(0)

    frame_list_batch = []

    for b in range(bz):
        images = videos[b]

        w = images[0].size(0)
        h = images[0].size(1)
        num_frames = images.size(0)
        frame_list = []

        for i in range(0, num_frames):
            frame_list.append(cv.cvtColor(images[i].numpy(), cv.COLOR_BGR2GRAY))

        frame_list_batch.append(np.stack(frame_list, axis=-1))

    SG3I = np.stack(frame_list_batch, axis=0)
    #cv2_imshow(SG3I[0])

    return torch.Tensor(SG3I)

# %% [markdown]
# # Mount drive

# %%
import os
import io
from google.colab import drive

# Mount google drive
DRIVE_MOUNT='/content/drive'

drive.mount(DRIVE_MOUNT)

# create folder to write data to
DATA_FOLDER = os.path.join(DRIVE_MOUNT, 'Shared drives', 'CIS680 Final Project', 'data')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Get dataset state files (don't need to run)

# %%
import torchvision.transforms as tf

transform = tf.Compose([tf.Resize(256), tf.RandomCrop(224)])

train_dataset = HMDB51(DATA_FOLDER)
test_dataset = HMDB51(DATA_FOLDER)

train_dataset.init_data(DATA_FOLDER, frames_per_clip=3, transform=transform)
torch.save(train_dataset.state_dict(), DATA_FOLDER + "/train_dataset_3.pt")

test_dataset.init_data(DATA_FOLDER, frames_per_clip=3, train=False, transform=transform)
torch.save(test_dataset.state_dict(), DATA_FOLDER + "/test_dataset_3.pt")
# Out:
# {'brush_hair': 0, 'cartwheel': 1, 'catch': 2, 'chew': 3, 'clap': 4, 'climb': 5, 'climb_stairs': 6, 'dive': 7, 'draw_sword': 8, 'dribble': 9, 'drink': 10, 'eat': 11, 'fall_floor': 12, 'fencing': 13, 'flic_flac': 14, 'golf': 15, 'handstand': 16, 'hit': 17, 'hug': 18, 'jump': 19, 'kick': 20, 'kick_ball': 21, 'kiss': 22, 'laugh': 23, 'pick': 24, 'pour': 25, 'pullup': 26, 'punch': 27, 'push': 28, 'pushup': 29, 'ride_bike': 30, 'ride_horse': 31, 'run': 32, 'shake_hands': 33, 'shoot_ball': 34, 'shoot_bow': 35, 'shoot_gun': 36, 'sit': 37, 'situp': 38, 'smile': 39, 'smoke': 40, 'somersault': 41, 'stand': 42, 'swing_baseball': 43, 'sword': 44, 'sword_exercise': 45, 'talk': 46, 'throw': 47, 'turn': 48, 'walk': 49, 'wave': 50}
# HBox(children=(FloatProgress(value=0.0, max=330.0), HTML(value='')))
# {'brush_hair': 0, 'cartwheel': 1, 'catch': 2, 'chew': 3, 'clap': 4, 'climb': 5, 'climb_stairs': 6, 'dive': 7, 'draw_sword': 8, 'dribble': 9, 'drink': 10, 'eat': 11, 'fall_floor': 12, 'fencing': 13, 'flic_flac': 14, 'golf': 15, 'handstand': 16, 'hit': 17, 'hug': 18, 'jump': 19, 'kick': 20, 'kick_ball': 21, 'kiss': 22, 'laugh': 23, 'pick': 24, 'pour': 25, 'pullup': 26, 'punch': 27, 'push': 28, 'pushup': 29, 'ride_bike': 30, 'ride_horse': 31, 'run': 32, 'shake_hands': 33, 'shoot_ball': 34, 'shoot_bow': 35, 'shoot_gun': 36, 'sit': 37, 'situp': 38, 'smile': 39, 'smoke': 40, 'somersault': 41, 'stand': 42, 'swing_baseball': 43, 'sword': 44, 'sword_exercise': 45, 'talk': 46, 'throw': 47, 'turn': 48, 'walk': 49, 'wave': 50}
# HBox(children=(FloatProgress(value=0.0, max=97.0), HTML(value='')))

# %% [markdown]
# # Load Dataset and Dataloaders

# %%
import matplotlib.pyplot as plt

train_dataset = HMDB51(DATA_FOLDER)
test_dataset = HMDB51(DATA_FOLDER)

train_dataset.load_state_dict(torch.load(DATA_FOLDER + "/train_dataset_3.pt"))
test_dataset.load_state_dict(torch.load(DATA_FOLDER + "/test_dataset_3.pt"))

batch_size = 128 #256
train_build_loader = BuildDataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
train_loader = train_build_loader.loader()
test_build_loader = BuildDataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
test_loader = test_build_loader.loader()

print("Length of train_loader: {}".format(len(train_loader)))
print("Length of test_loader: {}".format(len(test_loader)))
# Out:
# Length of train_loader: 3768
# Length of test_loader: 1104

# %% [markdown]
# # Debuggin Visualization

# %%
state = train_dataset.state_dict()

for iter, data in enumerate(train_loader, 0):
    videos = data["videos"]
    labels = data["labels"]
    indexes = data["indexes"]

    plt.imshow(videos[0][0])

    flows = getOpticalFlow(videos)

    SG3I = getSG3I(videos)

    break
# Out:
# ['/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/April_09_brush_hair_u_nm_np1_ba_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/April_09_brush_hair_u_nm_np1_ba_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/April_09_brush_hair_u_nm_np1_ba_goo_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np1_ba_goo_4.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np1_ri_med_3.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np2_le_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np2_le_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np2_le_med_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Blonde_being_brushed_brush_hair_f_nm_np2_ri_med_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Blonde_being_brushed_brush_hair_u_cm_np2_ri_med_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_f_nm_np1_fr_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_f_nm_np1_fr_goo_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_f_nm_np1_fr_goo_4.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_f_nm_np1_le_goo_3.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_f_nm_np1_ri_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_h_cm_np2_ri_goo_6.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brunette_Foxyanya_ultra_silky_long_hair_brushing_hairjob_brush_hair_h_nm_np2_ri_goo_5.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_Hair_with_Beth_brush_hair_h_nm_np1_le_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_Hair_with_Beth_brush_hair_u_nm_np1_fr_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_Hair_with_Beth_brush_hair_u_nm_np1_fr_goo_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_Her_Hair__[_NEW_AUDIO_]_UPDATED!!!!_brush_hair_h_cm_np1_le_goo_3.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_hair__the_right_way_brush_hair_u_nm_np1_fr_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_hair__the_right_way_brush_hair_u_nm_np1_fr_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_hair__the_right_way_brush_hair_u_nm_np1_fr_goo_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_my_Long_Hair__February_2009_brush_hair_u_nm_np1_ba_goo_1.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_my_Long_Hair__February_2009_brush_hair_u_nm_np1_ba_goo_2.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_my_Long_Hair__February_2009_brush_hair_u_nm_np1_fr_goo_0.avi', '/content/drive/Shared drives/CIS680 Final Project/data/train/brush_hair/Brushing_my_hair_-_December_2008_brush_hair_u_cm_np1_ba_goo_1. ...
# <torch.utils.data.dataloader.DataLoader object at 0x7fceeb4c1668>
# /usr/local/lib/python3.6/dist-packages/torchvision/io/video.py:117: UserWarning: The pts_unit 'pts' gives wrong results and will be removed in a follow-up version. Please use pts_unit 'sec'.
#   + "follow-up version. Please use pts_unit 'sec'."
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FCEEB1065F8>

# %% [markdown]
# # Temporal Model

# %%
import torch
from torch.nn import functional as F
from torchvision import transforms
from torch import nn, Tensor
import random
import torchvision
import torchvision.models as models
import torch.optim as optim

class TemporalStream(torch.nn.Module):

    def __init__(self,
                 device='cuda',
                 num_classes=51,
                 dropout_probability=0.5):

        # Initialize the stream layers
        super(TemporalStream, self).__init__()
        self.device = device
        self.num_classes = num_classes

        # Backbone
        self.temporal = models.resnet50(pretrained=True)
        for param in self.temporal.parameters():
            param.requires_grad = True

        self.temporal.fc = nn.Sequential(nn.Linear(2048, 1024),
                                nn.ReLU(),
                                nn.Dropout(p=dropout_probability),
                                nn.Linear(1024, self.num_classes),
                                nn.ReLU(),
                                nn.Dropout(p=dropout_probability),
                                nn.Softmax())

    def forward(self, X):
        X = self.temporal(X)
        return X

    def compute_loss(self, output, target):
        criterion = nn.CrossEntropyLoss()
        loss = criterion(output, target)
        return loss

# %% [markdown]
# # Train & Test

# %%
def train(epoch):
    temporal.train()
    counter = 0
    if epoch == last_epoch:
        counter = last_iter + 1
    train_loss = 0
    log_interval = 50
    save_interval = 200

    epoch_loss = []
    log_int_loss = 0
    for iter, data in enumerate(train_loader, 0):

        # Unpack data
        videos = data["videos"]
        labels = torch.tensor(data["labels"])
        indexes = data["indexes"]

        # Network input handling
        videos = videos.type(torch.FloatTensor)
        SG3I = getSG3I(videos)
        SG3I = SG3I.permute(0,3,1,2)
        SG3I = SG3I.to(device)

        # Network output
        optimizer.zero_grad()
        output = temporal(SG3I)
        output = output.to(device)
        labels = labels.to(device)

        # calculate losses
        loss = temporal.compute_loss(output, labels)

        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        # Logging Interval
        log_int_loss += loss.item()
        epoch_loss.append(loss.item())

        if counter == 0:
            print('Epoch: ', epoch, ', Batch: ', iter, ', loss avg over log interval: ', log_int_loss)
            train_loss_list.append(train_loss / batch_size)
            train_counter.append((iter + 1) * batch_size + epoch * len(train_loader.dataset))
            log_int_loss = 0
        elif counter % log_interval == log_interval - 1:
            print('Epoch: ', epoch, ', Batch: ', iter, ', loss avg over log interval: ', log_int_loss / log_interval)
            train_loss_list.append(train_loss / batch_size)
            train_counter.append((iter + 1) * batch_size + epoch * len(train_loader.dataset))
            log_int_loss = 0

        if counter % save_interval == save_interval - 1:
            print('saving model for iter: ', counter)
            save_path = os.path.join(EPOCH_SAVE_PREFIX, 'temporal_epoch' + str(epoch) + '_iter_' + str(counter))
            torch.save({
                'epoch': epoch,
                'train_total_loss_list': train_loss_list,
                'epoch_total_loss_list': epoch_loss_list,
                'test_loss_list': test_loss_list,
                'train_counter': train_counter,
                'accuracy_list': accuracy_list,
                'model_state_dict': temporal.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
            }, save_path)

        if counter == 3768:
          break

        counter += 1

    avg_loss = sum(epoch_loss) / len(epoch_loss)
    epoch_loss_list.append(avg_loss)
    print('Epoch: ', epoch, ', avg total loss: ', avg_loss)


def test():
    temporal.eval()
    test_loss = 0
    correct = 0

    # Data Loop
    with torch.no_grad():
        for iter, data in enumerate(test_loader, 0):

            # Unpack data
            videos = data["videos"]
            labels = torch.tensor(data["labels"])
            indexes = data["indexes"]

            # Network input handling
            videos = videos.type(torch.FloatTensor)
            labels = labels.to(device)
            SG3I = getSG3I(videos)
            SG3I = SG3I.permute(0,3,1,2)
            SG3I = SG3I.to(device)

            # Network output
            output = temporal(SG3I)
            output = output.to(device)

            # calculate losses
            loss = temporal.compute_loss(output, labels)

            test_loss += loss.item()

            # calculate number of correct predictions in batch
            correct += sum(torch.argmax(output,1) == labels).item()
            if iter % 100 == 0:
                print ("iter  ", iter)
                print("accuracy so far = ", correct / ((iter + 1) * len(labels)))
    
    # Log
    test_loss_list.append(test_loss / len(test_loader.dataset))
    accuracy = correct / len(test_loader.dataset)
    accuracy_list.append(accuracy)
    print('Avg Validation Loss: ', test_loss / len(test_loader.dataset))
    print('Accuracy: ', accuracy)

# %% [markdown]
# # Train Loop

# %%
EPOCH_SAVE_PREFIX = '/content/drive/Shared drives/CIS680 Final Project/models/temporal_SG3I/'

# Device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
torch.random.manual_seed(1)

# model
learning_rate = 0.001
temporal = TemporalStream()
temporal.to(device)
optimizer = optim.SGD(temporal.parameters(), lr=learning_rate, momentum=0.9)

# Epochs
num_epochs = 50

# Logging setup: train
train_loss_list = []
epoch_loss_list = []
train_counter = []

# Logging setup: test
test_loss_list = []
accuracy_list = []
epoch_list = np.arange(num_epochs)

# epoch loop
for epoch in range(num_epochs):

    # Train & Validate
    train(epoch)
    test()

    # Save Model Version
    save_path = os.path.join(EPOCH_SAVE_PREFIX, 'temporal_epoch' + str(epoch))
    torch.save({
        'epoch': epoch,
        'train_total_loss_list': train_loss_list,
        'epoch_total_loss_list': epoch_loss_list,
        'test_loss_list': test_loss_list,
        'train_counter': train_counter,
        'accuracy_lsit': accuracy_list,
        'model_state_dict': temporal.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, save_path)

    print("Epoch %d/%d Completed" % (epoch, num_epochs - 1))
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/io/video.py:117: UserWarning: The pts_unit 'pts' gives wrong results and will be removed in a follow-up version. Please use pts_unit 'sec'.
#   + "follow-up version. Please use pts_unit 'sec'."
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch:  0 , Batch:  0 , loss avg over log interval:  3.932321548461914
# Epoch:  0 , Batch:  49 , loss avg over log interval:  3.853197627067566
# Epoch:  0 , Batch:  99 , loss avg over log interval:  3.9316504049301146
# Epoch:  0 , Batch:  149 , loss avg over log interval:  3.9315021944046022
# Epoch:  0 , Batch:  199 , loss avg over log interval:  3.9311947441101074
# saving model for iter:  199
# Epoch:  0 , Batch:  249 , loss avg over log interval:  3.930749287605286
# Epoch:  0 , Batch:  299 , loss avg over log interval:  3.9303851747512817
# Epoch:  0 , Batch:  349 , loss avg over log interval:  3.929409971237183
# Epoch:  0 , Batch:  399 , loss avg over log interval:  3.927215838432312
# saving model for iter:  399
# Epoch:  0 , Batch:  449 , loss avg over log interval:  3.9212195110321044
# Epoch:  0 , Batch:  499 , loss avg over log interval:  3.909051704406738
# Epoch:  0 , Batch:  549 , loss avg over log interval:  3.9044515037536622
# Epoch:  0 , Batch:  599 , loss avg over log interval:  3.9023592281341553
# saving model for iter:  599
# Epoch:  0 , Batch:  649 , loss avg over log interval:  3.9014468812942504
# Epoch:  0 , Batch:  699 , loss avg over log interval:  3.8973928594589236
# Epoch:  0 , Batch:  749 , loss avg over log interval:  3.8949581718444826
# Epoch:  0 , Batch:  799 , loss avg over log interval:  3.8972358083724976
# saving model for iter:  799
# Epoch:  0 , Batch:  849 , loss avg over log interval:  3.8935396766662596
# Epoch:  0 , Batch:  899 , loss avg over log interval:  3.89308021068573
# Epoch:  0 , Batch:  949 , loss avg over log interval:  3.897446103096008
# Epoch:  0 , Batch:  999 , loss avg over log interval:  3.8934814167022704
# saving model for iter:  999
# Epoch:  0 , Batch:  1049 , loss avg over log interval:  3.895879445075989
# Epoch:  0 , Batch:  1099 , loss avg over log interval:  3.8910914993286134
# Epoch:  0 , Batch:  1149 , loss avg over log interval:  3.896673016548157
# Epoch:  0 , Batch:  1199 , loss avg over log interval:  3.895389590263367
# saving model for iter:  1199
# Epoch:  0 , Batch:  1249 , loss avg over log interval:  3.8977070569992067
# Epoch:  0 , Batch:  1299 , loss avg over log interval:  3.8880745220184325
# Epoch:  0 , Batch:  1349 , loss avg over log interval:  3.891652855873108
# Epoch:  0 , Batch:  1399 , loss avg over log interval:  3.8905611515045164
# saving model for iter:  1399
# Epoch:  0 , Batch:  1449 , loss avg over log interval:  3.8931035089492796
# Epoch:  0 , Batch:  1499 , loss avg over log interval:  3.8900459718704226
# Epoch:  0 , Batch:  1549 , loss avg over log interval:  3.888892192840576
# Epoch:  0 , Batch:  1599 , loss avg over log interval:  3.8954834842681887
# saving model for iter:  1599
# Epoch:  0 , Batch:  1649 , loss avg over log interval:  3.888808960914612
# Epoch:  0 , Batch:  1699 , loss avg over log interval:  3.8859126663208006
# Epoch:  0 , Batch:  1749 , loss avg over log interval:  3.8843021631240844
# Epoch:  0 , Batch:  1799 , loss avg over log interval:  3.8828876066207885
# saving model for iter:  1799
# Epoch:  0 , Batch:  1849 , loss avg over log interval:  3.8826348304748537
# Epoch:  0 , Batch:  1899 , loss avg over log interval:  3.8805957937240603
# Epoch:  0 , Batch:  1949 , loss avg over log interval:  3.880161657333374
# Epoch:  0 , Batch:  1999 , loss avg over log interval:  3.876451168060303
# saving model for iter:  1999
# Epoch:  0 , Batch:  2049 , loss avg over log interval:  3.87722571849823
# Epoch:  0 , Batch:  2099 , loss avg over log interval:  3.870338487625122
# Epoch:  0 , Batch:  2149 , loss avg over log interval:  3.874788317680359

# %% [markdown]
# # Resume Train Loop

# %%
import timeit

EPOCH_SAVE_PREFIX = '/content/drive/Shared drives/CIS680 Final Project/models/temporal_SG3I/'

# Device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
torch.random.manual_seed(1)

# model
learning_rate = 0.001
temporal = TemporalStream()
temporal.to(device)
optimizer = optim.SGD(temporal.parameters(), lr=learning_rate, momentum=0.9)

# Load model
last_epoch = 7
last_iter = 2599
network_path = EPOCH_SAVE_PREFIX + 'temporal_epoch' + str(last_epoch) + '_iter_' + str(last_iter)
checkpoint = torch.load(network_path)
temporal.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Epochs
num_epochs = 11

# Logging setup: train
train_loss_list = checkpoint['train_total_loss_list']
epoch_loss_list = checkpoint['epoch_total_loss_list']
train_counter = checkpoint['train_counter']
test_loss_list = checkpoint['test_loss_list']
accuracy_list = checkpoint['accuracy_list']
epoch_list = np.arange(num_epochs)

# Mid epoch retrain: 0, end of epoch retrain: 1
switch_epoch = 0

# epoch loop
for epoch in range(last_epoch + switch_epoch, num_epochs): 

    # Train & Validate
    train(epoch)
    test()

    # Save Model Version
    save_path = os.path.join(EPOCH_SAVE_PREFIX, 'temporal_epoch' + str(epoch))
    torch.save({
        'epoch': epoch,
        'train_total_loss_list': train_loss_list,
        'epoch_total_loss_list': epoch_loss_list,
        'test_loss_list': test_loss_list,
        'train_counter': train_counter,
        'accuracy_list': accuracy_list,
        'model_state_dict': temporal.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, save_path)

    print("Epoch %d/%d Completed" % (epoch, num_epochs - 1))
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/io/video.py:117: UserWarning: The pts_unit 'pts' gives wrong results and will be removed in a follow-up version. Please use pts_unit 'sec'.
#   + "follow-up version. Please use pts_unit 'sec'."
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch:  7 , Batch:  49 , loss avg over log interval:  3.6189580583572387
# Epoch:  7 , Batch:  99 , loss avg over log interval:  3.608939561843872
# Epoch:  7 , Batch:  149 , loss avg over log interval:  3.613851385116577
# Epoch:  7 , Batch:  199 , loss avg over log interval:  3.6109411096572877
# saving model for iter:  2799
# Epoch:  7 , Batch:  249 , loss avg over log interval:  3.6078413105010987
# Epoch:  7 , Batch:  299 , loss avg over log interval:  3.6263201808929444
# Epoch:  7 , Batch:  349 , loss avg over log interval:  3.6171922969818113
# Epoch:  7 , Batch:  399 , loss avg over log interval:  3.6129521703720093
# saving model for iter:  2999
# Epoch:  7 , Batch:  449 , loss avg over log interval:  3.6123831987380983
# Epoch:  7 , Batch:  499 , loss avg over log interval:  3.6153286266326905
# Epoch:  7 , Batch:  549 , loss avg over log interval:  3.621390061378479
# Epoch:  7 , Batch:  599 , loss avg over log interval:  3.6100333595275877
# saving model for iter:  3199
# Epoch:  7 , Batch:  649 , loss avg over log interval:  3.62652569770813
# Epoch:  7 , Batch:  699 , loss avg over log interval:  3.61655743598938
# Epoch:  7 , Batch:  749 , loss avg over log interval:  3.6106048727035525
# Epoch:  7 , Batch:  799 , loss avg over log interval:  3.620224609375
# saving model for iter:  3399
# Epoch:  7 , Batch:  849 , loss avg over log interval:  3.6161426067352296
# Epoch:  7 , Batch:  899 , loss avg over log interval:  3.6160790061950685
# Epoch:  7 , Batch:  949 , loss avg over log interval:  3.6163458824157715
# Epoch:  7 , Batch:  999 , loss avg over log interval:  3.610147066116333
# saving model for iter:  3599
# Epoch:  7 , Batch:  1049 , loss avg over log interval:  3.611636590957642
# Epoch:  7 , Batch:  1099 , loss avg over log interval:  3.593969688415527
# Epoch:  7 , Batch:  1149 , loss avg over log interval:  3.61423321723938
# Epoch:  7 , avg total loss:  3.6143851000799696
# iter   0
# accuracy so far =  0.921875
# iter   100
# accuracy so far =  0.47578898514851486
# iter   200
# accuracy so far =  0.48993314676616917
# iter   300
# accuracy so far =  0.4534364617940199
# iter   400
# accuracy so far =  0.39296290523690774
# iter   500
# accuracy so far =  0.42943799900199603
# iter   600
# accuracy so far =  0.44459754575707155
# iter   700
# accuracy so far =  0.4606923145506419
# iter   800
# accuracy so far =  0.4896906210986267
# iter   900
# accuracy so far =  0.4797620699223085
# iter   1000
# accuracy so far =  0.4883475899100899
# iter   1100
# accuracy so far =  0.4872559037238874
# Avg Validation Loss:  0.028233576714488267
# Accuracy:  0.4861348077562954
# Epoch 7/10 Completed
# Epoch:  8 , Batch:  0 , loss avg over log interval:  3.62195086479187
# Epoch:  8 , Batch:  49 , loss avg over log interval:  3.5357196950912475
# Epoch:  8 , Batch:  99 , loss avg over log interval:  3.616997575759888
# Epoch:  8 , Batch:  149 , loss avg over log interval:  3.6195496559143066
# Epoch:  8 , Batch:  199 , loss avg over log interval:  3.6108078384399414
# saving model for iter:  199
# Epoch:  8 , Batch:  249 , loss avg over log interval:  3.615717358589172
# Epoch:  8 , Batch:  299 , loss avg over log interval:  3.6067482662200927
# Epoch:  8 , Batch:  349 , loss avg over log interval:  3.6289914798736573
# Epoch:  8 , Batch:  399 , loss avg over log interval:  3.6145024347305297
# saving model for iter:  399
# Epoch:  8 , Batch:  449 , loss avg over log interval:  3.6232114171981813
# Epoch:  8 , Batch:  499 , loss avg over log interval:  3.6262745571136477
# Epoch:  8 , Batch:  549 , loss avg over log interval:  3.6172518730163574
# Epoch:  8 , Batch:  599 , loss avg over log interval:  3.5971102571487426
# saving model for iter:  599
# Epoch:  8 , Batch:  649 , loss avg over log interval:  3.6256455612182616
# Epoch:  8 , Batch:  699 , loss avg over log interval:  3.603830590248108
# Epoch:  8 , Batch:  749 , loss avg over log interval:  3.608712086677551
# Epoch:  8 , Batch:  799 , loss avg over log interval:  3.6093037271499635
# saving model for iter:  799
# Epoch:  8 , Batch:  849 , loss avg over log interval:  3.609244384765625
# Epoch:  8 , Batch:  899 , loss avg over log interval:  3.6135417461395263
# Epoch:  8 , Batch:  949 , loss avg over log interval:  3.616271743774414
# Epoch:  8 , Batch:  999 , loss avg over log interval:  3.6071856594085694
# saving model for iter:  999
# Epoch:  8 , Batch:  1049 , loss avg over log interval:  3.5961554145812986
# Epoch:  8 , Batch:  1099 , loss avg over log interval:  3.6114784812927248
# Epoch:  8 , Batch:  1149 , loss avg over log interval:  3.6076827239990235
# Epoch:  8 , Batch:  1199 , loss avg over log interval:  3.610912113189697
# saving model for iter:  1199
# Epoch:  8 , Batch:  1249 , loss avg over log interval:  3.606492338180542
# Epoch:  8 , Batch:  1299 , loss avg over log interval:  3.6097935390472413
# Epoch:  8 , Batch:  1349 , loss avg over log interval:  3.6202574443817137
# Epoch:  8 , Batch:  1399 , loss avg over log interval:  3.6037711334228515
# saving model for iter:  1399
# Epoch:  8 , Batch:  1449 , loss avg over log interval:  3.613128089904785
# Epoch:  8 , Batch:  1499 , loss avg over log interval:  3.6139492177963257
# Epoch:  8 , Batch:  1549 , loss avg over log interval:  3.604320149421692
# Epoch:  8 , Batch:  1599 , loss avg over log interval:  3.6001594400405885
# saving model for iter:  1599
# Epoch:  8 , Batch:  1649 , loss avg over log interval:  3.610161371231079
# Epoch:  8 , Batch:  1699 , loss avg over log interval:  3.6071107149124146
# Epoch:  8 , Batch:  1749 , loss avg over log interval:  3.600261106491089
# Epoch:  8 , Batch:  1799 , loss avg over log interval:  3.604126477241516
# saving model for iter:  1799
# Epoch:  8 , Batch:  1849 , loss avg over log interval:  3.6062759876251222
# Epoch:  8 , Batch:  1899 , loss avg over log interval:  3.6074713039398194
# Epoch:  8 , Batch:  1949 , loss avg over log interval:  3.599559841156006
# Epoch:  8 , Batch:  1999 , loss avg over log interval:  3.613356909751892
# saving model for iter:  1999
# Epoch:  8 , Batch:  2049 , loss avg over log interval:  3.599463229179382
# Epoch:  8 , Batch:  2099 , loss avg over log interval:  3.607096734046936
# Epoch:  8 , Batch:  2149 , loss avg over log interval:  3.605646414756775
# Epoch:  8 , Batch:  2199 , loss avg over log interval:  3.6009314918518065
# saving model for iter:  2199
# Epoch:  8 , Batch:  2249 , loss avg over log interval:  3.598065204620361
# Epoch:  8 , Batch:  2299 , loss avg over log interval:  3.6069982147216795
# Epoch:  8 , Batch:  2349 , loss avg over log interval:  3.5956747484207154
# Epoch:  8 , Batch:  2399 , loss avg over log interval:  3.606894669532776
# saving model for iter:  2399
# Epoch:  8 , Batch:  2449 , loss avg over log interval:  3.604975018501282
# Epoch:  8 , Batch:  2499 , loss avg over log interval:  3.5977307033538817
# Epoch:  8 , Batch:  2549 , loss avg over log interval:  3.6126752281188965
# Epoch:  8 , Batch:  2599 , loss avg over log interval:  3.6018883275985716
# saving model for iter:  2599
# Epoch:  8 , Batch:  2649 , loss avg over log interval:  3.6013186740875245
# Epoch:  8 , Batch:  2699 , loss avg over log interval:  3.5993644428253173
# Epoch:  8 , Batch:  2749 , loss avg over log interval:  3.6092982292175293
# Epoch:  8 , Batch:  2799 , loss avg over log interval:  3.5892663621902465
# saving model for iter:  2799
# Epoch:  8 , Batch:  2849 , loss avg over log interval:  3.5953681230545045
# Epoch:  8 , Batch:  2899 , loss avg over log interval:  3.590439548492432
# Epoch:  8 , Batch:  2949 , loss avg over log interval:  3.6021628189086914
# Epoch:  8 , Batch:  2999 , loss avg over log interval:  3.6048140048980715
# saving model for iter:  2999
# Epoch:  8 , Batch:  3049 , loss avg over log interval:  3.5925877904891967
# Epoch:  8 , Batch:  3099 , loss avg over log interval:  3.5955851221084596
# Epoch:  8 , Batch:  3149 , loss avg over log interval:  3.6032977724075317
# Epoch:  8 , Batch:  3199 , loss avg over log interval:  3.594575343132019
# saving model for iter:  3199
# Epoch:  8 , Batch:  3249 , loss avg over log interval:  3.605911545753479
# Epoch:  8 , Batch:  3299 , loss avg over log interval:  3.6024444580078123
# Epoch:  8 , Batch:  3349 , loss avg over log interval:  3.5946680021286013
# Epoch:  8 , Batch:  3399 , loss avg over log interval:  3.6070201635360717
# saving model for iter:  3399
# Epoch:  8 , Batch:  3449 , loss avg over log interval:  3.5975182914733885
# Epoch:  8 , Batch:  3499 , loss avg over log interval:  3.5943199157714845
# Epoch:  8 , Batch:  3549 , loss avg over log interval:  3.604826693534851
# Epoch:  8 , Batch:  3599 , loss avg over log interval:  3.600213022232056
# saving model for iter:  3599
# Epoch:  8 , Batch:  3649 , loss avg over log interval:  3.614130835533142
# Epoch:  8 , Batch:  3699 , loss avg over log interval:  3.6005909729003904
# Epoch:  8 , Batch:  3749 , loss avg over log interval:  3.591705470085144
# Epoch:  8 , avg total loss:  3.6060165386417617
# iter   0
# accuracy so far =  0.953125
# iter   100
# accuracy so far =  0.48754641089108913
# iter   200
# accuracy so far =  0.5336986940298507
# iter   300
# accuracy so far =  0.4865292774086379
# iter   400
# accuracy so far =  0.42339463840399
# iter   500
# accuracy so far =  0.44880551397205587
# iter   600
# accuracy so far =  0.48575291181364394
# iter   700
# accuracy so far =  0.4955755171184023
# iter   800
# accuracy so far =  0.51801459113608
# iter   900
# accuracy so far =  0.5035984322974473
# iter   1000
# accuracy so far =  0.509888548951049
# iter   1100
# accuracy so far =  0.5079473206176204
# Avg Validation Loss:  0.02815121510891803
# Accuracy:  0.5067786170913184
# Epoch 8/10 Completed
# Epoch:  9 , Batch:  0 , loss avg over log interval:  3.5888257026672363
# Epoch:  9 , Batch:  49 , loss avg over log interval:  3.525306191444397
# Epoch:  9 , Batch:  99 , loss avg over log interval:  3.597346487045288
# Epoch:  9 , Batch:  149 , loss avg over log interval:  3.606178488731384
# Epoch:  9 , Batch:  199 , loss avg over log interval:  3.599036750793457
# saving model for iter:  199
# Epoch:  9 , Batch:  249 , loss avg over log interval:  3.5941111040115357
# Epoch:  9 , Batch:  299 , loss avg over log interval:  3.6025301742553713
# Epoch:  9 , Batch:  349 , loss avg over log interval:  3.592357850074768
# Epoch:  9 , Batch:  399 , loss avg over log interval:  3.598840889930725
# saving model for iter:  399
# Epoch:  9 , Batch:  449 , loss avg over log interval:  3.593304786682129
# Epoch:  9 , Batch:  499 , loss avg over log interval:  3.591866135597229
# Epoch:  9 , Batch:  549 , loss avg over log interval:  3.6078473854064943
# Epoch:  9 , Batch:  599 , loss avg over log interval:  3.596158881187439
# saving model for iter:  599
# Epoch:  9 , Batch:  649 , loss avg over log interval:  3.599536280632019
# Epoch:  9 , Batch:  699 , loss avg over log interval:  3.603630738258362
# Epoch:  9 , Batch:  749 , loss avg over log interval:  3.59663227558136
# Epoch:  9 , Batch:  799 , loss avg over log interval:  3.5941930770874024
# saving model for iter:  799
# Epoch:  9 , Batch:  849 , loss avg over log interval:  3.6008057975769043
# Epoch:  9 , Batch:  899 , loss avg over log interval:  3.5839671087265015
# Epoch:  9 , Batch:  949 , loss avg over log interval:  3.6031073141098022
# Epoch:  9 , Batch:  999 , loss avg over log interval:  3.5973712730407716
# saving model for iter:  999
# Epoch:  9 , Batch:  1049 , loss avg over log interval:  3.5912345457077026
# Epoch:  9 , Batch:  1099 , loss avg over log interval:  3.5878768253326414
# Epoch:  9 , Batch:  1149 , loss avg over log interval:  3.594388790130615
# Epoch:  9 , Batch:  1199 , loss avg over log interval:  3.5892282915115357
# saving model for iter:  1199
# Epoch:  9 , Batch:  1249 , loss avg over log interval:  3.595587692260742
# Epoch:  9 , Batch:  1299 , loss avg over log interval:  3.5964862632751466
# Epoch:  9 , Batch:  1349 , loss avg over log interval:  3.5893587112426757
# Epoch:  9 , Batch:  1399 , loss avg over log interval:  3.5975420379638674
# saving model for iter:  1399
# Epoch:  9 , Batch:  1449 , loss avg over log interval:  3.5806822299957277
# Epoch:  9 , Batch:  1499 , loss avg over log interval:  3.6011349964141846
# Epoch:  9 , Batch:  1549 , loss avg over log interval:  3.5906008529663085
# Epoch:  9 , Batch:  1599 , loss avg over log interval:  3.5944450664520264
# saving model for iter:  1599
# Epoch:  9 , Batch:  1649 , loss avg over log interval:  3.601170048713684
# Epoch:  9 , Batch:  1699 , loss avg over log interval:  3.5989784526824953
# Epoch:  9 , Batch:  1749 , loss avg over log interval:  3.600419282913208
# Epoch:  9 , Batch:  1799 , loss avg over log interval:  3.5843780565261842
# saving model for iter:  1799
# Epoch:  9 , Batch:  1849 , loss avg over log interval:  3.5961065769195555
# Epoch:  9 , Batch:  1899 , loss avg over log interval:  3.5771461391448973
# Epoch:  9 , Batch:  1949 , loss avg over log interval:  3.58695912361145
# Epoch:  9 , Batch:  1999 , loss avg over log interval:  3.609096436500549
# saving model for iter:  1999
# Epoch:  9 , Batch:  2049 , loss avg over log interval:  3.598638343811035
# Epoch:  9 , Batch:  2099 , loss avg over log interval:  3.583357563018799
# Epoch:  9 , Batch:  2149 , loss avg over log interval:  3.5890918731689454
# Epoch:  9 , Batch:  2199 , loss avg over log interval:  3.5862530183792116
# saving model for iter:  2199
# Epoch:  9 , Batch:  2249 , loss avg over log interval:  3.584256954193115
# Epoch:  9 , Batch:  2299 , loss avg over log interval:  3.585977568626404
# Epoch:  9 , Batch:  2349 , loss avg over log interval:  3.596172780990601
# Epoch:  9 , Batch:  2399 , loss avg over log interval:  3.584388966560364
# saving model for iter:  2399
# Epoch:  9 , Batch:  2449 , loss avg over log interval:  3.58793532371521
# Epoch:  9 , Batch:  2499 , loss avg over log interval:  3.583113751411438
# Epoch:  9 , Batch:  2549 , loss avg over log interval:  3.5932037925720213
# Epoch:  9 , Batch:  2599 , loss avg over log interval:  3.5876764106750487
# saving model for iter:  2599
# Epoch:  9 , Batch:  2649 , loss avg over log interval:  3.585993618965149
# Epoch:  9 , Batch:  2699 , loss avg over log interval:  3.5961762714385985
# Epoch:  9 , Batch:  2749 , loss avg over log interval:  3.5865872001647947
# Epoch:  9 , Batch:  2799 , loss avg over log interval:  3.5845725631713865
# saving model for iter:  2799
# Epoch:  9 , Batch:  2849 , loss avg over log interval:  3.591925764083862
# Epoch:  9 , Batch:  2899 , loss avg over log interval:  3.5920566940307617
# Epoch:  9 , Batch:  2949 , loss avg over log interval:  3.5953755378723145
# Epoch:  9 , Batch:  2999 , loss avg over log interval:  3.5839017248153686
# saving model for iter:  2999
# Epoch:  9 , Batch:  3049 , loss avg over log interval:  3.5900173664093016
# Epoch:  9 , Batch:  3099 , loss avg over log interval:  3.581752452850342
# Epoch:  9 , Batch:  3149 , loss avg over log interval:  3.606738624572754
# Epoch:  9 , Batch:  3199 , loss avg over log interval:  3.5885630369186403
# saving model for iter:  3199
# Epoch:  9 , Batch:  3249 , loss avg over log interval:  3.5931945848464966
# Epoch:  9 , Batch:  3299 , loss avg over log interval:  3.5862112283706664
# Epoch:  9 , Batch:  3349 , loss avg over log interval:  3.57927686214447
# Epoch:  9 , Batch:  3399 , loss avg over log interval:  3.589517078399658
# saving model for iter:  3399
# Epoch:  9 , Batch:  3449 , loss avg over log interval:  3.584980263710022
# Epoch:  9 , Batch:  3499 , loss avg over log interval:  3.588085012435913
# Epoch:  9 , Batch:  3549 , loss avg over log interval:  3.5809990262985227
# Epoch:  9 , Batch:  3599 , loss avg over log interval:  3.590087113380432
# saving model for iter:  3599
# Epoch:  9 , Batch:  3649 , loss avg over log interval:  3.5845153951644897
# Epoch:  9 , Batch:  3699 , loss avg over log interval:  3.5785263109207155
# Epoch:  9 , Batch:  3749 , loss avg over log interval:  3.590437774658203
# Epoch:  9 , avg total loss:  3.5920205475038784
# iter   0
# accuracy so far =  0.9609375
# iter   100
# accuracy so far =  0.46055074257425743
# iter   200
# accuracy so far =  0.5097947761194029
# iter   300
# accuracy so far =  0.4666735880398671
# iter   400
# accuracy so far =  0.4115492518703242
# iter   500
# accuracy so far =  0.4438310878243513
# iter   600
# accuracy so far =  0.485544925124792
# iter   700
# accuracy so far =  0.5186786733238231
# iter   800
# accuracy so far =  0.5412375156054932
# iter   900
# accuracy so far =  0.5209662874583796
# iter   1000
# accuracy so far =  0.5251233141858141
# iter   1100
# accuracy so far =  0.517597638510445
# Avg Validation Loss:  0.028106989339350064
# Accuracy:  0.5164067311844704
# Epoch 9/10 Completed
# Epoch:  10 , Batch:  0 , loss avg over log interval:  3.6436896324157715
# Epoch:  10 , Batch:  49 , loss avg over log interval:  3.5116720676422117
# Epoch:  10 , Batch:  99 , loss avg over log interval:  3.574093165397644
# Epoch:  10 , Batch:  149 , loss avg over log interval:  3.5788771724700927
# Epoch:  10 , Batch:  199 , loss avg over log interval:  3.574176573753357
# saving model for iter:  199
# Epoch:  10 , Batch:  249 , loss avg over log interval:  3.587092170715332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7d6986cf6f5d> in <module>()
#      39
#      40     # Train & Validate
# ---> 41     train(epoch)
#      42     test()
#      43
#
# <ipython-input-9-b0891b11d0d4> in train(epoch)
#      10     epoch_loss = []
#      11     log_int_loss = 0
# ---> 12     for iter, data in enumerate(train_loader, 0):
#      13
#      14         videos = data["videos"]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-3-245fc2e2c289> in __getitem__(self, idx)
#      91         if self.transform is not None:
#      92             video = video.permute(0, 3, 1, 2)
# ---> 93             video = self.transform(video)
#      94             video = video.permute(0, 2, 3, 1)
#      95
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in forward(self, img)
#     265             PIL Image or Tensor: Rescaled image.
#     266         """
# --> 267         return F.resize(img, self.size, self.interpolation)
#     268
#     269     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py in resize(img, size, interpolation)
#     310         return F_pil.resize(img, size=size, interpolation=interpolation)
#     311
# --> 312     return F_t.resize(img, size=size, interpolation=interpolation)
#     313
#     314
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py in resize(img, size, interpolation)
#     840     align_corners = False if mode in ["bilinear", "bicubic"] else None
#     841
# --> 842     img = interpolate(img, size=[size_h, size_w], mode=mode, align_corners=align_corners)
#     843
#     844     if need_squeeze:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor)
#    3149     if input.dim() == 4 and mode == 'bilinear':
#    3150         assert align_corners is not None
# -> 3151         return torch._C._nn.upsample_bilinear2d(input, output_size, align_corners, scale_factors)
#    3152     if input.dim() == 5 and mode == 'trilinear':
#    3153         assert align_corners is not None
#
# KeyboardInterrupt:

# %% [markdown]
# # Plotting

# %%
EPOCH_SAVE_PREFIX = '/content/drive/Shared drives/CIS680 Final Project/models/temporal_SG3I/'

# Device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
torch.random.manual_seed(1)

# Load params
last_epoch = 7

# load data
network_path = EPOCH_SAVE_PREFIX + 'temporal_epoch' + str(last_epoch)
checkpoint = torch.load(network_path)
train_loss_list = checkpoint['train_total_loss_list']
epoch_loss_list = checkpoint['epoch_total_loss_list']
train_counter = checkpoint['train_counter']
test_loss_list = checkpoint['test_loss_list']
accuracy_list = checkpoint['accuracy_list']
epoch_list = np.arange(last_epoch+1)

# plots
fig = plt.figure()
plt.plot(epoch_loss_list, color='blue')
plt.legend(['Temporal Train Loss'], loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Total Loss')

fig = plt.figure()
plt.plot(test_loss_list, color='green')
plt.legend(['Temporal Validation Loss'], loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Total Loss')

fig = plt.figure()
plt.plot(accuracy_list, color='red')
plt.legend(['Temporal Validation Accuracy'], loc='lower right')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()
